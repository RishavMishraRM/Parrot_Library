# %%
! pip install git+https://github.com/PrithivirajDamodaran/Parrot.git
# Out:
# Collecting git+https://github.com/PrithivirajDamodaran/Parrot.git
#   Cloning https://github.com/PrithivirajDamodaran/Parrot.git to /tmp/pip-req-build-n1ldbmwo
#   Running command git clone -q https://github.com/PrithivirajDamodaran/Parrot.git /tmp/pip-req-build-n1ldbmwo
# Collecting transformers
#   Downloading https://files.pythonhosted.org/packages/b0/9e/5b80becd952d5f7250eaf8fc64b957077b12ccfe73e9c03d37146ab29712/transformers-4.6.0-py3-none-any.whl (2.3MB)
#      |████████████████████████████████| 2.3MB 9.0MB/s
# Collecting sentencepiece
#   Downloading https://files.pythonhosted.org/packages/f5/99/e0808cb947ba10f575839c43e8fafc9cc44e4a7a2c8f79c60db48220a577/sentencepiece-0.1.95-cp37-cp37m-manylinux2014_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 26.3MB/s
# Collecting python-Levenshtein
#   Downloading https://files.pythonhosted.org/packages/2a/dc/97f2b63ef0fa1fd78dcb7195aca577804f6b2b51e712516cc0e902a9a201/python-Levenshtein-0.12.2.tar.gz (50kB)
#      |████████████████████████████████| 51kB 6.0MB/s
# Collecting sentence-transformers
#   Downloading https://files.pythonhosted.org/packages/14/9d/abacb6f7bb63df39285c55bb51b6403a7fd93ac2aea48b01f6215175446c/sentence-transformers-1.1.1.tar.gz (81kB)
#      |████████████████████████████████| 81kB 9.3MB/s
# Collecting fuzzywuzzy
#   Downloading https://files.pythonhosted.org/packages/43/ff/74f23998ad2f93b945c0309f825be92e04e0348e062026998b5eefef4c33/fuzzywuzzy-0.18.0-py2.py3-none-any.whl
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers->parrot==1.0) (1.19.5)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers->parrot==1.0) (2019.12.20)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers->parrot==1.0) (4.0.1)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/75/ee/67241dc87f266093c533a2d4d3d69438e57d7a90abb216fa076e7d475d4a/sacremoses-0.0.45-py3-none-any.whl (895kB)
#      |████████████████████████████████| 901kB 40.9MB/s
# Collecting huggingface-hub==0.0.8
#   Downloading https://files.pythonhosted.org/packages/a1/88/7b1e45720ecf59c6c6737ff332f41c955963090a18e72acbcbeac6b25e86/huggingface_hub-0.0.8-py3-none-any.whl
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading https://files.pythonhosted.org/packages/ae/04/5b870f26a858552025a62f1649c20d29d2672c02ff3c3fb4c688ca46467a/tokenizers-0.10.2-cp37-cp37m-manylinux2010_x86_64.whl (3.3MB)
#      |████████████████████████████████| 3.3MB 23.5MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers->parrot==1.0) (20.9)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers->parrot==1.0) (3.0.12)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers->parrot==1.0) (4.41.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers->parrot==1.0) (2.23.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from python-Levenshtein->parrot==1.0) (56.1.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers->parrot==1.0) (1.8.1+cu101)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence-transformers->parrot==1.0) (0.9.1+cu101)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sentence-transformers->parrot==1.0) (0.22.2.post1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers->parrot==1.0) (1.4.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence-transformers->parrot==1.0) (3.2.5)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers->parrot==1.0) (3.4.1)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers->parrot==1.0) (3.7.4.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers->parrot==1.0) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers->parrot==1.0) (8.0.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers->parrot==1.0) (1.0.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers->parrot==1.0) (2.4.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers->parrot==1.0) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers->parrot==1.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers->parrot==1.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers->parrot==1.0) (1.24.3)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence-transformers->parrot==1.0) (7.1.2)
# Building wheels for collected packages: parrot, python-Levenshtein, sentence-transformers
#   Building wheel for parrot (setup.py) ... done
#   Created wheel for parrot: filename=parrot-1.0-cp37-none-any.whl size=8685 sha256=fb33729ad012fee38f7adcebbaddebec0c10f4b0ebc67aa53b03e8ec031e5415
#   Stored in directory: /tmp/pip-ephem-wheel-cache-qk6jvagc/wheels/96/16/2c/b241910909ea2fc05552298ed25a2b1383f369c672f8aee255
#   Building wheel for python-Levenshtein (setup.py) ... done
#   Created wheel for python-Levenshtein: filename=python_Levenshtein-0.12.2-cp37-cp37m-linux_x86_64.whl size=149817 sha256=e15061d94113f7a4908b959bfa7db37a1b770ec06897583342d3f07555ad5240
#   Stored in directory: /root/.cache/pip/wheels/b3/26/73/4b48503bac73f01cf18e52cd250947049a7f339e940c5df8fc
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-1.1.1-cp37-none-any.whl size=123338 sha256=fe73ec13ab0fd96c35880069dc9400a0e6cd49c5c2fb83caeffc25e421df87e0
#   Stored in directory: /root/.cache/pip/wheels/5e/89/29/45e45adc162b50f97f71801e8b07947c9cfe2b3ae7dbf37896
# Successfully built parrot python-Levenshtein sentence-transformers
# Installing collected packages: sacremoses, huggingface-hub, tokenizers, transformers, sentencepiece, python-Levenshtein, sentence-transformers, fuzzywuzzy, parrot
# Successfully installed fuzzywuzzy-0.18.0 huggingface-hub-0.0.8 parrot-1.0 python-Levenshtein-0.12.2 sacremoses-0.0.45 sentence-transformers-1.1.1 sentencepiece-0.1.95 tokenizers-0.10.2 transformers-4.6.0

# %%
# Import libraries
from parrot import Parrot
import torch
import warnings
warnings.filterwarnings("ignore")

# %%
# For reproducibility
def random_state(seed):
  torch.manual_seed(seed)
  if torch.cuda.is_available():
    torch.cuda.manual_seed_all(seed)

random_state(1234)

# %%
#Init models (make sure you init ONLY once if you integrate this to your code)
parrot = Parrot(model_tag="prithivida/parrot_paraphraser_on_T5", use_gpu=False)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1373.0, style=ProgressStyle(description…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=791656.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1786.0, style=ProgressStyle(description…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1889.0, style=ProgressStyle(description…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=891737400.0, style=ProgressStyle(descri…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=908.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1629486723.0, style=ProgressStyle(descr…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=898822.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=456318.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1355863.0, style=ProgressStyle(descript…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=26.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=476.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=437985387.0, style=ProgressStyle(descri…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=231508.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=112.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=48.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, max=305584576.0), HTML(value='')))

# %%
phrases = ["From were can I Learn Data Science?"]

# %%
for phrase in phrases:
  print("-"*100)
  print("Input_phrase: ", phrase)
  print("-"*100)
  para_phrases = parrot.augment(input_phrase=phrase)
  for para_phrase in para_phrases:
   print(para_phrase)
# Out:
# ----------------------------------------------------------------------------------------------------
# Input_phrase:  From were can I Learn Data Science?
# ----------------------------------------------------------------------------------------------------
# ('where should i start learning data science?', 25)
# ('how can one start learning data science?', 25)
# ('where do i start learning data science?', 24)
# ('which are the best places to learn data science?', 22)
# ('how i can learn data science?', 20)
# ('how can i learn data science?', 18)
# ('where can i learn data science?', 17)

# %%
phrases = ["What's the most dangerous thing with which we deal in AI?"]

# %%
for phrase in phrases:
  print("-"*100)
  print("Input_phrase: ", phrase)
  print("-"*100)
  para_phrases = parrot.augment(input_phrase=phrase)
  for para_phrase in para_phrases:
   print(para_phrase)
# Out:
# ----------------------------------------------------------------------------------------------------
# Input_phrase:  What's the most dangerous thing with which we deal in AI?
# ----------------------------------------------------------------------------------------------------
# ('tell me the most dangerous thing to deal with in artificial intelligence?', 45)
# ('tell me the most dangerous part of dealing with ai?', 40)
# ('tell me the most dangerous thing about ai?', 37)
# ('what is the most dangerous thing in ai?', 33)
# ('tell me the most dangerous thing that happens in ai?', 31)
# ('list some of the most dangerous things with which ai is used?', 28)
# ("what's the most dangerous thing that we do with ai?", 26)
# ("what's the most dangerous thing that we deal with in ai?", 25)
